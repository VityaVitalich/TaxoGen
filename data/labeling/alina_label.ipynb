# %%
import pandas as pd
from label_util import LabelingTool
import os

# %%
#читаем ваш датафрейс
df = pd.read_csv('alina.csv')
df = df.set_index('wordnet_id')

# %%
df
# Out:
#                             subset         core_synset     core_lemma  \
# wordnet_id
# 13388245                  appendix           coin.n.01           coin
# 13389105                  appendix         bawbee.n.01         bawbee
# 13389194                  appendix         bezant.n.01         bezant
# 13388111                  appendix         change.n.08         change
# 13389864                  appendix          crown.n.06          crown
# ...                            ...                 ...            ...
# 74157104          predict_hypernym        oldster.n.01        oldster
# 4514738           predict_hypernym     upper_deck.n.01     upper_deck
# 14966192    simple_triplet_2parent          nylon.n.01          nylon
# 6474122           predict_hypernym  questionnaire.n.01  questionnaire
# 13931145          predict_hypernym     friendship.n.01     friendship
#
#                                      hypernym_synsets  \
# wordnet_id
# 13388245                             ['coinage.n.01']
# 13389105                                ['coin.n.01']
# 13389194                                ['coin.n.01']
# 13388111                                ['coin.n.01']
# 13389864                                ['coin.n.01']
# ...                                               ...
# 74157104                               ['adult.n.01']
# 4514738                                 ['deck.n.01']
# 14966192    ['man-made_fiber.n.01', 'polyamide.n.01']
# 6474122                                 ['form.n.08']
# 13931145                        ['relationship.n.03']
#
#                                             cohyponym_synsets  \
# wordnet_id
# 13388245                                        ['coin.n.01']
# 13389105    ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 13389194    ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 13388111    ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 13389864    ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# ...                                                       ...
# 74157104    ['brachycephalic.n.01', 'caregiver.n.02', 'cat...
# 4514738     ['afterdeck.n.01', 'flight_deck.n.01', 'forede...
# 14966192                 ['acrylic_fiber.n.01', 'nylon.n.01']
# 6474122     ['application_form.n.01', 'claim_form.n.01', '...
# 13931145    ['account.n.03', 'acquaintance.n.02', 'affilia...
#
#                                              wikimedia_images  \
# wordnet_id
# 13388245    ['https://upload.wikimedia.org/wikipedia/commo...
# 13389105    ['https://upload.wikimedia.org/wikipedia/commo...
# 13389194    ['https://upload.wikimedia.org/wikipedia/commo...
# 13388111    ['https://upload.wikimedia.org/wikipedia/commo...
# 13389864    ['https://upload.wikimedia.org/wikipedia/commo...
# ...                                                       ...
# 74157104    ['https://upload.wikimedia.org/wikipedia/commo...
# 4514738     ['https://upload.wikimedia.org/wikipedia/commo...
# 14966192    ['https://upload.wikimedia.org/wikipedia/commo...
# 6474122     ['https://upload.wikimedia.org/wikipedia/commo...
# 13931145    ['https://upload.wikimedia.org/wikipedia/commo...
#
#                                                image_filename  \
# wordnet_id
# 13388245    India, Kushan, Vasudeva II, 3rd century - Coin...
# 13389105                          Mary bawbee 1542 127326.jpg
# 13389194       Crusader coins of the Kingdom of Jerusalem.jpg
# 13388111    Change in Average Temperature With Fahrenheit.svg
# 13389864                                     서봉총 금관 금제드리개.jpg
# ...                                                       ...
# 74157104                   Старик (oldster) (50904206177).jpg
# 4514738                                   Upper Deck Logo.svg
# 14966192                                     Черные чулки.jpg
# 6474122                 Questionnaire-checklist-completed.png
# 13931145    Human–canine friendship - girl hugging her dog...
#
#                                                    definition  \
# wordnet_id
# 13388245    a flat metal piece (usually a disc) used as money
# 13389105                 an old Scottish coin of little value
# 13389194    a gold coin of the Byzantine Empire; widely ci...
# 13388111    coins of small denomination regarded collectively
# 13389864                    an English coin worth 5 shillings
# ...                                                       ...
# 74157104                                    an elderly person
# 4514738                                         a higher deck
# 14966192    a thermoplastic polyamide; a family of strong ...
# 6474122     a form containing a set of questions; submitte...
# 13931145             the state of being friends (or friendly)
#
#                                                     model_a  \
# wordnet_id
# 13388245      playgroundai_playground-v2.5-1024px-aesthetic
# 13389105                     runwayml_stable-diffusion-v1-5
# 13389194              PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 13388111                             DeepFloyd_IF-I-XL-v1.0
# 13389864                                          retrieval
# ...                                                     ...
# 74157104          Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 4514738     stabilityai_stable-diffusion-3-medium-diffusers
# 14966192      playgroundai_playground-v2.5-1024px-aesthetic
# 6474122                              stabilityai_sdxl-turbo
# 13931145          Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
#
#                                               model_b
# wordnet_id
# 13388245                                    retrieval
# 13389105     stabilityai_stable-diffusion-xl-base-1.0
# 13389194               runwayml_stable-diffusion-v1-5
# 13388111              kandinsky-community_kandinsky-3
# 13389864                       DeepFloyd_IF-I-XL-v1.0
# ...                                               ...
# 74157104                       prompthero_openjourney
# 4514738      stabilityai_stable-diffusion-xl-base-1.0
# 14966192               runwayml_stable-diffusion-v1-5
# 6474122     Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 13931145                       DeepFloyd_IF-I-XL-v1.0
#
# [842 rows x 10 columns]

# %%
#df = df.drop(columns=['assessor_vitya'])

# %%
labeler = LabelingTool(
    dataset=df,
    assessor_id='alina', # ваше имя 
    image_path='/home/data/v.moskvoretskii/taxo_demo_images/images', #путь до разархивированных картинок
    save2path='alina.csv', # куда сохранится
    img_type='.png', # не нужно, внутри пофикшено все
    ignore_all_labeled=True
    )
# Out:
# Labeling is stopped!

# %%
labeler.label_samples()
# Out:
# VBox(children=(HBox(children=(Output(), Output()), layout=Layout(align_items='center')), VBox(children=(Output…

# %%
df
# Out:
#                                   subset          core_synset      core_lemma  \
# wordnet_id
# 5410315                 predict_hypernym    gonadotropin.n.01    gonadotropin
# 33877584                  appendix_llama         coinage.n.01     numismatics
# 56250900                  appendix_llama            coin.n.01             bee
# 70890935                  appendix_llama            coin.n.01       gold coin
# 66203715                  appendix_llama            coin.n.01  transformation
# ...                                  ...                  ...             ...
# 92219553          predict_hypernym_llama        activity.n.01    self-worship
# 65034633          predict_hypernym_llama           adult.n.01         oldster
# 25851699          predict_hypernym_llama            deck.n.01            deck
# 85363317    simple_triplet_2parent_llama  man-made_fiber.n.01           nylon
# 41772405          predict_hypernym_llama            form.n.08   questionnaire
#
#              hypernym_synsets  \
# wordnet_id
# 5410315      ['hormone.n.01']
# 33877584    ['currency.n.01']
# 56250900     ['coinage.n.01']
# 70890935     ['coinage.n.01']
# 66203715     ['coinage.n.01']
# ...                       ...
# 92219553         ['act.n.02']
# 65034633      ['person.n.01']
# 25851699    ['platform.n.01']
# 85363317       ['fiber.n.01']
# 41772405    ['document.n.01']
#
#                                             cohyponym_synsets  \
# wordnet_id
# 5410315     ['adrenocorticotropic_hormone.n.01', 'adrenost...
# 33877584    ['cash.n.01', 'eurocurrency.n.01', 'hard_curre...
# 56250900                                                   []
# 70890935                                                   []
# 66203715                                                   []
# ...                                                       ...
# 92219553    ['acquiring.n.01', 'action.n.01', 'assumption....
# 65034633    ['abator.n.01', 'abjurer.n.01', 'abomination.n...
# 25851699    ['auction_block.n.01', 'bandstand.n.01', 'catw...
# 85363317    ['bassine.n.01', 'bristle.n.01', 'byssus.n.01'...
# 41772405    ['ballot.n.01', 'brevet.n.01', 'capitulation.n...
#
#                                              wikimedia_images  \
# wordnet_id
# 5410315     ['https://upload.wikimedia.org/wikipedia/commo...
# 33877584    ['https://upload.wikimedia.org/wikipedia/commo...
# 56250900    ['https://upload.wikimedia.org/wikipedia/commo...
# 70890935    ['https://upload.wikimedia.org/wikipedia/commo...
# 66203715    ['https://upload.wikimedia.org/wikipedia/commo...
# ...                                                       ...
# 92219553    ['https://upload.wikimedia.org/wikipedia/commo...
# 65034633    ['https://upload.wikimedia.org/wikipedia/commo...
# 25851699    ['https://upload.wikimedia.org/wikipedia/commo...
# 85363317    ['https://upload.wikimedia.org/wikipedia/commo...
# 41772405    ['https://upload.wikimedia.org/wikipedia/commo...
#
#                                                image_filename  \
# wordnet_id
# 5410315     Estrogen provocation test and gonadotropin sur...
# 33877584    Coin collectors and enthusiasts by Yogabrata C...
# 56250900                 Bee Collecting Pollen 2004-08-14.jpg
# 70890935    Gold coin of the Kushan empire, king Vasudeva ...
# 66203715                         Bacterial Transformation.svg
# ...                                                       ...
# 92219553    2016 Bahai House of Worship Langenhain 1 ks01.jpg
# 65034633                   Старик (oldster) (50904206177).jpg
# 25851699                     Bridge and deck of Gullbritt.jpg
# 85363317                                     Черные чулки.jpg
# 41772405                Questionnaire-checklist-completed.png
#
#                                                    definition  \
# wordnet_id
# 5410315     hormone secreted by the anterior pituitary gla...
# 33877584                                   coins collectively
# 56250900    a flat metal piece (usually a disc) used as money
# 70890935    a flat metal piece (usually a disc) used as money
# 66203715    a flat metal piece (usually a disc) used as money
# ...                                                       ...
# 92219553                                any specific behavior
# 65034633        a fully developed person from maturity onward
# 25851699         any of various platforms built into a vessel
# 85363317    fiber created from natural materials or by che...
# 41772405     a printed document with spaces in which to write
#
#                                                     model_a  \
# wordnet_id
# 5410315                              prompthero_openjourney
# 33877584                             prompthero_openjourney
# 56250900              PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 70890935              PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 66203715           stabilityai_stable-diffusion-xl-base-1.0
# ...                                                     ...
# 92219553           stabilityai_stable-diffusion-xl-base-1.0
# 65034633           stabilityai_stable-diffusion-xl-base-1.0
# 25851699    stabilityai_stable-diffusion-3-medium-diffusers
# 85363317                             DeepFloyd_IF-I-XL-v1.0
# 41772405           stabilityai_stable-diffusion-xl-base-1.0
#
#                                                     model_b  assessor_vitya
# wordnet_id
# 5410315     stabilityai_stable-diffusion-3-medium-diffusers             3.0
# 33877584                             stabilityai_sdxl-turbo             1.0
# 56250900                             DeepFloyd_IF-I-XL-v1.0             0.0
# 70890935                                          retrieval             1.0
# 66203715      playgroundai_playground-v2.5-1024px-aesthetic             3.0
# ...                                                     ...             ...
# 92219553                             prompthero_openjourney             NaN
# 65034633                     runwayml_stable-diffusion-v1-5             NaN
# 25851699                    kandinsky-community_kandinsky-3             NaN
# 85363317              PixArt-alpha_PixArt-Sigma-XL-2-512-MS             NaN
# 41772405          Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers             NaN
#
# [842 rows x 11 columns]

# %%
len(df.index[df['assessor_vitya'].notna()])
# Out:
# 558

# %%
output = pd.read_csv('alina.csv', index_col=0) # проверяем что все ок
