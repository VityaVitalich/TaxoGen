# %%
import pandas as pd
from label_util import LabelingTool
import os

# %%
#читаем ваш датафрейс
df = pd.read_csv('data/vitya_flux_def.csv')
df = df.set_index('wordnet_id')
#760
#771
#824

# %%
df
# Out:
#             Unnamed: 0                    subset           core_synset  \
# wordnet_id
# 29148617          1595          predict_hypernym  genetic_disease.n.01
# 2053030           1598          predict_hypernym          surpass.v.02
# 93221214          1603          predict_hypernym        plaything.n.01
# 3818090           1606    simple_triplet_2parent         neomycin.n.01
# 4259202           1613    simple_triplet_2parent         solenoid.n.01
# ...                ...                       ...                   ...
# 61635816          2431    predict_hypernym_llama           spirit.n.04
# 18845198          2432    predict_hypernym_llama            adult.n.01
# 69489691          2434  leafs_and_no_leafs_llama            white.n.01
# 91790573          2468    predict_hypernym_llama     professional.n.01
# 91980352          2469    predict_hypernym_llama         modality.n.03
#
#                  core_lemma                        hypernym_synsets  \
# wordnet_id
# ...

# %%
#df = df.drop(columns=['assessor_vitya'])

# %%
labeler = LabelingTool(
    dataset=df,
    assessor_id='vitya', # ваше имя 
    image_path='/home/data/v.moskvoretskii/cache/taxo_demo_images/images', #путь до разархивированных картинок
    save2path='vitya_nodef_flux.csv', # куда сохранится
    img_type='.png', # не нужно, внутри пофикшено все
    ignore_all_labeled=True
    )
# Out:
# All samples are labeled!

# %%
labeler.label_samples()

# %%
df
# Out:
#             Unnamed: 0                        subset          core_synset  \
# wordnet_id
# 5410315           1684              predict_hypernym    gonadotropin.n.01
# 33877584          1685                appendix_llama         coinage.n.01
# 56250900          1686                appendix_llama            coin.n.01
# 70890935          1687                appendix_llama            coin.n.01
# 66203715          1688                appendix_llama            coin.n.01
# ...                ...                           ...                  ...
# 92219553          2521        predict_hypernym_llama        activity.n.01
# 65034633          2522        predict_hypernym_llama           adult.n.01
# 25851699          2523        predict_hypernym_llama            deck.n.01
# 85363317          2524  simple_triplet_2parent_llama  man-made_fiber.n.01
# 41772405          2525        predict_hypernym_llama            form.n.08
#
#                 core_lemma   hypernym_synsets  \
# wordnet_id
# ...

# %%
len(df.index[df['assessor_vitya'].notna()])
# Out:
# 842

# %%
output = pd.read_csv('test_output.csv', index_col=0) # проверяем что все ок

# %%
df1 = pd.read_csv('vitya_def.csv')

# %%
df1
# Out:
#      wordnet_id  Unnamed: 0                        subset  \
# 0       5410315        1684              predict_hypernym
# 1      33877584        1685                appendix_llama
# 2      56250900        1686                appendix_llama
# 3      70890935        1687                appendix_llama
# 4      66203715        1688                appendix_llama
# ..          ...         ...                           ...
# 837    92219553        2521        predict_hypernym_llama
# 838    65034633        2522        predict_hypernym_llama
# 839    25851699        2523        predict_hypernym_llama
# 840    85363317        2524  simple_triplet_2parent_llama
# 841    41772405        2525        predict_hypernym_llama
#
#              core_synset      core_lemma   hypernym_synsets  \
# 0      gonadotropin.n.01    gonadotropin   ['hormone.n.01']
# 1           coinage.n.01     numismatics  ['currency.n.01']
# 2              coin.n.01             bee   ['coinage.n.01']
# ...
