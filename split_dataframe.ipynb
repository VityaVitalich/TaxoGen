# %%
import pandas as pd
import random
import os
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('main.tsv', sep='\t')

# %%
models_list = os.listdir('/home/data/v.moskvoretskii/taxo_demo_images/images/')

# %%
df['core_synset'][0]
# Out:
# 'coin.n.01'

# %%
df['definition'] = [wn.synset(df['core_synset'][i]).definition() for i in tqdm(range(len(df)))]
# Out:
# 100%|██████████| 3370/3370 [00:00<00:00, 20595.30it/s]

# %%
df
# Out:
#                         subset  wordnet_id            core_synset  \
# 0                     appendix    13388245              coin.n.01
# 1                     appendix    13389105            bawbee.n.01
# 2                     appendix    13389194            bezant.n.01
# 3                     appendix    13388111            change.n.08
# 4                     appendix    13389864             crown.n.06
# ...                        ...         ...                    ...
# 3365  leafs_and_no_leafs_llama    41796839              area.n.03
# 3366    predict_hypernym_llama    36389327       card_player.n.01
# 3367    predict_hypernym_llama    27347584  domestic_partner.n.01
# 3368    predict_hypernym_llama    13967420         body_part.n.01
# 3369    predict_hypernym_llama    78890307           hormone.n.01
#
#          core_lemma    hypernym_synsets  \
# 0              coin    ['coinage.n.01']
# 1            bawbee       ['coin.n.01']
# 2            bezant       ['coin.n.01']
# 3            change       ['coin.n.01']
# 4             crown       ['coin.n.01']
# ...             ...                 ...
# 3365     renal area  ['body_part.n.01']
# 3366  bridge player     ['player.n.01']
# 3367  married woman     ['person.n.01']
# 3368        abdomen       ['part.n.03']
# 3369   gonadotropin  ['secretion.n.02']
#
#                                       cohyponym_synsets  \
# 0                                         ['coin.n.01']
# 1     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 2     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 3     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 4     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# ...                                                 ...
# 3365  ['abdomen.n.01', 'adnexa.n.01', 'ambulacrum.n....
# 3366  ['ballplayer.n.01', 'billiard_player.n.01', 'b...
# 3367  ['abator.n.01', 'abjurer.n.01', 'abomination.n...
# 3368  ['acicula.n.01', 'base.n.04', 'corner.n.09', '...
# 3369  ['autacoid.n.01', 'ganoin.n.01', 'intestinal_j...
#
#                                        wikimedia_images  \
# 0     ['https://upload.wikimedia.org/wikipedia/commo...
# 1     ['https://upload.wikimedia.org/wikipedia/commo...
# 2     ['https://upload.wikimedia.org/wikipedia/commo...
# 3     ['https://upload.wikimedia.org/wikipedia/commo...
# 4     ['https://upload.wikimedia.org/wikipedia/commo...
# ...                                                 ...
# 3365  ['https://upload.wikimedia.org/wikipedia/commo...
# 3366  ['https://upload.wikimedia.org/wikipedia/commo...
# 3367  ['https://upload.wikimedia.org/wikipedia/commo...
# 3368  ['https://upload.wikimedia.org/wikipedia/commo...
# 3369  ['https://upload.wikimedia.org/wikipedia/commo...
#
#                                          image_filename  \
# 0     India, Kushan, Vasudeva II, 3rd century - Coin...
# 1                           Mary bawbee 1542 127326.jpg
# 2        Crusader coins of the Kingdom of Jerusalem.jpg
# 3     Change in Average Temperature With Fahrenheit.svg
# 4                                      서봉총 금관 금제드리개.jpg
# ...                                                 ...
# 3365  CT of sclerotic lesions in the skull in renal ...
# 3366                  Kevin Collins (bridge player).jpg
# 3367                The Woman He Married (1922) - 4.jpg
# 3368                   Abdomen-periumbilical region.png
# 3369  Estrogen provocation test and gonadotropin sur...
#
#                                              definition
# 0     a flat metal piece (usually a disc) used as money
# 1                  an old Scottish coin of little value
# 2     a gold coin of the Byzantine Empire; widely ci...
# 3     coins of small denomination regarded collectively
# 4                     an English coin worth 5 shillings
# ...                                                 ...
# 3365  a part of an animal that has a special functio...
# 3366  someone who plays (or knows how to play) card ...
# 3367  a person (not necessarily a spouse) with whom ...
# 3368  any part of an organism such as an organ or ex...
# 3369  the secretion of an endocrine gland that is tr...
#
# [3370 rows x 9 columns]

# %%
# target_size = 4 * 1000
# rows_needed = target_size - len(df)
# additional_rows = df.sample(n=rows_needed, replace=True)
# expanded_df = pd.concat([df, additional_rows], ignore_index=True)

#models_list = ['SD3', 'SDXL', 'SDXL_Turbo', 'Kandinsky', 'PixArt_Sigma', 'Playground', 'IF', 'Openjourney', 'Hunyuan-DiT', 'SD_V1.5', 'Retrieved']

def sample_model_pair(models_list):
    return random.sample(models_list, 2)

# Adding the sampled pairs to the dataframe
df[['model_a', 'model_b']] = df.apply(lambda row: pd.Series(sample_model_pair(models_list)), axis=1)

# %%
df
# Out:
#                         subset  wordnet_id            core_synset  \
# 0                     appendix    13388245              coin.n.01
# 1                     appendix    13389105            bawbee.n.01
# 2                     appendix    13389194            bezant.n.01
# 3                     appendix    13388111            change.n.08
# 4                     appendix    13389864             crown.n.06
# ...                        ...         ...                    ...
# 3365  leafs_and_no_leafs_llama    41796839              area.n.03
# 3366    predict_hypernym_llama    36389327       card_player.n.01
# 3367    predict_hypernym_llama    27347584  domestic_partner.n.01
# 3368    predict_hypernym_llama    13967420         body_part.n.01
# 3369    predict_hypernym_llama    78890307           hormone.n.01
#
#          core_lemma    hypernym_synsets  \
# 0              coin    ['coinage.n.01']
# 1            bawbee       ['coin.n.01']
# 2            bezant       ['coin.n.01']
# 3            change       ['coin.n.01']
# 4             crown       ['coin.n.01']
# ...             ...                 ...
# 3365     renal area  ['body_part.n.01']
# 3366  bridge player     ['player.n.01']
# 3367  married woman     ['person.n.01']
# 3368        abdomen       ['part.n.03']
# 3369   gonadotropin  ['secretion.n.02']
#
#                                       cohyponym_synsets  \
# 0                                         ['coin.n.01']
# 1     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 2     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 3     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# 4     ['bawbee.n.01', 'bezant.n.01', 'change.n.08', ...
# ...                                                 ...
# 3365  ['abdomen.n.01', 'adnexa.n.01', 'ambulacrum.n....
# 3366  ['ballplayer.n.01', 'billiard_player.n.01', 'b...
# 3367  ['abator.n.01', 'abjurer.n.01', 'abomination.n...
# 3368  ['acicula.n.01', 'base.n.04', 'corner.n.09', '...
# 3369  ['autacoid.n.01', 'ganoin.n.01', 'intestinal_j...
#
#                                        wikimedia_images  \
# 0     ['https://upload.wikimedia.org/wikipedia/commo...
# 1     ['https://upload.wikimedia.org/wikipedia/commo...
# 2     ['https://upload.wikimedia.org/wikipedia/commo...
# 3     ['https://upload.wikimedia.org/wikipedia/commo...
# 4     ['https://upload.wikimedia.org/wikipedia/commo...
# ...                                                 ...
# 3365  ['https://upload.wikimedia.org/wikipedia/commo...
# 3366  ['https://upload.wikimedia.org/wikipedia/commo...
# 3367  ['https://upload.wikimedia.org/wikipedia/commo...
# 3368  ['https://upload.wikimedia.org/wikipedia/commo...
# 3369  ['https://upload.wikimedia.org/wikipedia/commo...
#
#                                          image_filename  \
# 0     India, Kushan, Vasudeva II, 3rd century - Coin...
# 1                           Mary bawbee 1542 127326.jpg
# 2        Crusader coins of the Kingdom of Jerusalem.jpg
# 3     Change in Average Temperature With Fahrenheit.svg
# 4                                      서봉총 금관 금제드리개.jpg
# ...                                                 ...
# 3365  CT of sclerotic lesions in the skull in renal ...
# 3366                  Kevin Collins (bridge player).jpg
# 3367                The Woman He Married (1922) - 4.jpg
# 3368                   Abdomen-periumbilical region.png
# 3369  Estrogen provocation test and gonadotropin sur...
#
#                                              definition  \
# 0     a flat metal piece (usually a disc) used as money
# 1                  an old Scottish coin of little value
# 2     a gold coin of the Byzantine Empire; widely ci...
# 3     coins of small denomination regarded collectively
# 4                     an English coin worth 5 shillings
# ...                                                 ...
# 3365  a part of an animal that has a special functio...
# 3366  someone who plays (or knows how to play) card ...
# 3367  a person (not necessarily a spouse) with whom ...
# 3368  any part of an organism such as an organ or ex...
# 3369  the secretion of an endocrine gland that is tr...
#
#                                             model_a  \
# 0                            prompthero_openjourney
# 1          stabilityai_stable-diffusion-xl-base-1.0
# 2         Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 3         Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 4     playgroundai_playground-v2.5-1024px-aesthetic
# ...                                             ...
# 3365          PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 3366          PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 3367      Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 3368       stabilityai_stable-diffusion-xl-base-1.0
# 3369          PixArt-alpha_PixArt-Sigma-XL-2-512-MS
#
#                                               model_b
# 0           Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 1                                           retrieval
# 2     stabilityai_stable-diffusion-3-medium-diffusers
# 3                              stabilityai_sdxl-turbo
# 4                              DeepFloyd_IF-I-XL-v1.0
# ...                                               ...
# 3365                           DeepFloyd_IF-I-XL-v1.0
# 3366                           DeepFloyd_IF-I-XL-v1.0
# 3367                                        retrieval
# 3368                  kandinsky-community_kandinsky-3
# 3369    playgroundai_playground-v2.5-1024px-aesthetic
#
# [3370 rows x 11 columns]

# %%
sample = df.sample(100)

# %%
sample.to_csv('annotator_agreement.csv', index=0)

# %%
ad = pd.read_csv('annotator_agreement.csv')

# %%
ad
# Out:
#                     subset  wordnet_id           core_synset       core_lemma  \
# 0                 appendix     7896560         jug_wine.n.01         jug_wine
# 1           appendix_llama    46972907              pie.n.01            candy
# 2   predict_hypernym_llama    30823361         advocate.n.01          admirer
# 3                 appendix     2676566  acoustic_guitar.n.01  acoustic_guitar
# 4           appendix_llama    14942245         beverage.n.01             meat
# ..                     ...         ...                   ...              ...
# 95          appendix_llama    38161491             coat.n.01             coat
# 96      leafs_and_no_leafs      762889      horse-trade.v.01      horse-trade
# 97  predict_hypernym_llama    74999178        represent.v.09            write
# 98                appendix     4025130           puppet.n.03           puppet
# 99  predict_hypernym_llama    76096310        gastropod.n.01     marine snail
#
#                 hypernym_synsets  \
# 0                  ['wine.n.01']
# 1                ['pastry.n.02']
# 2                ['person.n.01']
# 3                ['guitar.n.01']
# 4   ['food.n.01', 'liquid.n.01']
# ..                           ...
# 95          ['overgarment.n.01']
# 96            ['negociate.v.05']
# 97            ['re-create.v.01']
# 98                 ['doll.n.01']
# 99              ['mollusk.n.01']
#
#                                     cohyponym_synsets  \
# 0   ['altar_wine.n.01', 'blush_wine.n.01', 'bordea...
# 1   ['baklava.n.01', 'dowdy.n.02', 'frangipane.n.0...
# 2   ['abator.n.01', 'abjurer.n.01', 'abomination.n...
# 3   ['acoustic_guitar.n.01', 'bass_guitar.n.01', '...
# 4   ['chyme.n.01', 'comestible.n.01', 'comfort_foo...
# ..                                                ...
# 95  ['aba.n.01', 'cloak.n.02', 'izar.n.01', 'snows...
# 96  ['parley.v.01', 'renegociate.v.01', 'treat.v.07']
# 97  ['act.v.03', 'fictionalize.v.01', 'forge.v.02'...
# 98  ['golliwog.n.01', 'kachina.n.03', 'paper_doll....
# 99  ['bivalve.n.01', 'cephalopod.n.01', 'chiton.n....
#
#                                      wikimedia_images  \
# 0   ['https://upload.wikimedia.org/wikipedia/commo...
# 1   ['https://upload.wikimedia.org/wikipedia/commo...
# 2   ['https://upload.wikimedia.org/wikipedia/commo...
# 3   ['https://upload.wikimedia.org/wikipedia/commo...
# 4   ['https://upload.wikimedia.org/wikipedia/commo...
# ..                                                ...
# 95  ['https://upload.wikimedia.org/wikipedia/commo...
# 96  ['https://upload.wikimedia.org/wikipedia/commo...
# 97  ['https://upload.wikimedia.org/wikipedia/commo...
# 98  ['https://upload.wikimedia.org/wikipedia/commo...
# 99  ['https://upload.wikimedia.org/wikipedia/commo...
#
#                                        image_filename  \
# 0                                        Jug wine.jpg
# 1             Ambigram Candy icon - pink animated.gif
# 2                 The Admirer by Eugenio Zampighi.jpg
# 3   Man playing an acoustic brazilian guitar (Viol...
# 4                Mercado Municipal (São Paulo) 07.jpg
# ..                                                ...
# 95                     Coat of arms of Seychelles.svg
# 96  Chatsworth Horse Trials, trade stands - geogra...
# 97                Fountain pen writing (literacy).jpg
# 98                                         PUPPET.jpg
# 99                   Scheme snail anatomy-numbers.svg
#
#                                             model_a  \
# 0                   kandinsky-community_kandinsky-3
# 1     playgroundai_playground-v2.5-1024px-aesthetic
# 2                                         retrieval
# 3                            DeepFloyd_IF-I-XL-v1.0
# 4     playgroundai_playground-v2.5-1024px-aesthetic
# ..                                              ...
# 95                  kandinsky-community_kandinsky-3
# 96  stabilityai_stable-diffusion-3-medium-diffusers
# 97    playgroundai_playground-v2.5-1024px-aesthetic
# 98            PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 99                           DeepFloyd_IF-I-XL-v1.0
#
#                                             model_b
# 0         Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 1                    runwayml_stable-diffusion-v1-5
# 2   stabilityai_stable-diffusion-3-medium-diffusers
# 3     playgroundai_playground-v2.5-1024px-aesthetic
# 4                   kandinsky-community_kandinsky-3
# ..                                              ...
# 95                           stabilityai_sdxl-turbo
# 96            PixArt-alpha_PixArt-Sigma-XL-2-512-MS
# 97                  kandinsky-community_kandinsky-3
# 98        Tencent-Hunyuan_HunyuanDiT-v1.2-Diffusers
# 99            PixArt-alpha_PixArt-Sigma-XL-2-512-MS
#
# [100 rows x 10 columns]

# %%
df.to_csv('main.csv', index=0)
